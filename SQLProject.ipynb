# %%
pip install mysql-connector-python pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing important libraries
import mysql.connector
import pandas as pd

# %%
connection = mysql.connector.connect(
user='root',
password='Vaishnavip@23',
host='localhost',
database='SQLProject'
)

# %%
# Create a cursor object to execute SQL queries
cursor = connection.cursor()

# %%
cursor.execute('SELECT * FROM Students')

# %%
Students = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# %%
cursor.execute('SELECT * FROM Courses')
Courses = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# %%
cursor.execute('SELECT * FROM Enrollments')
Enrollments = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# %%
#printing first 5 records from each table
print(Students.head(10))
# Out:
#    StudentID FirstName   LastName DateOfBirth Gender  \
# 0          1      John        Doe  2000-05-15      M
# 1          2      Jane      Smith  2001-02-28      F
# 2          3     David    Johnson  1999-08-10      M
# 3          4     Emily      Brown  2000-11-20      F
# 4          5   Michael     Wilson  2001-04-03      M
# 5          6    Sophia   Martinez  2000-09-08      F
# 6          7     Jacob     Taylor  2001-01-17      M
# 7          8  Isabella   Anderson  2000-06-25      F
# 8          9     Ethan     Thomas  2000-12-30      M
# 9         10    Olivia  Hernandez  2001-03-05      F
#
#                            Email         Phone
# 0           john.doe@example.com  123-456-7890
# 1         jane.smith@example.com  987-654-3210
# 2      david.johnson@example.com  555-123-4567
# 3        emily.brown@example.com  444-222-3333
# 4     michael.wilson@example.com  777-888-9999
# 5    sophia.martinez@example.com  111-222-3333
# ...

# %%
print(Courses.head(10))
# Out:
#    CourseID                        CourseName        Department  Credits
# 0       101  Introduction to Computer Science  Computer Science        3
# 1       102                        Calculus I       Mathematics        4
# 2       103               English Composition           English        3
# 3       104                    History of Art               Art        3
# 4       105            Chemistry Fundamentals         Chemistry        4
# 5       106                    Microeconomics         Economics        3
# 6       107        Introduction to Psychology        Psychology        3
# 7       108                         Sociology         Sociology        3
# 8       109             Physics for Engineers           Physics        4
# 9       110                 Digital Marketing         Marketing        3

# %%
print(Enrollments.head(10))
# Out:
#    EnrollmentID  StudentID  CourseID EnrollmentDate Grade
# 0             1          1       101     2023-09-01     A
# 1             2          2       102     2023-09-05    B+
# 2             3          3       103     2023-09-10    A-
# 3             4          4       104     2023-09-12     B
# 4             5          5       105     2023-09-15     A
# 5             6          6       106     2023-09-20    B+
# 6             7          7       107     2023-09-22    A-
# 7             8          8       108     2023-09-25     A
# 8             9          9       109     2023-09-30    B+
# 9            10         10       110     2023-10-01    A-

# %%
import matplotlib.pyplot as plt

# %%
course_counts = Enrollments['CourseID'].value_counts().head(10)

# Get course names
course_names = Courses.set_index('CourseID').loc[course_counts.index]['CourseName']

# Plotting the pie chart
plt.figure(figsize=(10, 8))
course_counts.plot(kind='pie', labels=course_names, autopct='%1.1f%%', startangle=140)
plt.title('Enrollments Distribution by Course',  fontweight='bold')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
df = Students['Gender'].value_counts()

# Plotting
plt.figure(figsize=(8, 6))
df.plot(kind='bar', color=['blue', 'pink'])
plt.title('Distribution of Students by Gender',  fontweight='bold')
plt.xlabel('Gender')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
enrollment_counts_by_department = enrollments_with_department['Department'].value_counts()

# Reset index to get 'Department' as a column
enrollment_counts_by_department = enrollment_counts_by_department.reset_index()

# Rename columns for clarity
enrollment_counts_by_department.columns = ['Department', 'Enrollment Count']

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(enrollment_counts_by_department['Department'], enrollment_counts_by_department['Enrollment Count'])
plt.title('Enrollment Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Enrollment Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
department_counts = Courses['Department'].value_counts()

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(department_counts, bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Courses Across Departments')
plt.xlabel('Number of Courses')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# %%
data = [
    [10, 20, 30, 40],
    [15, 25, 35, 45],
    [20, 30, 40, 50],
    [25, 35, 45, 55]
]

# Plotting the heat map
plt.figure(figsize=(8, 6))
sns.heatmap(data, annot=True, cmap='viridis')
plt.title('Heat Map')
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Department', y='StudentID', data=enrollments_with_department)
plt.title('Enrollment Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
